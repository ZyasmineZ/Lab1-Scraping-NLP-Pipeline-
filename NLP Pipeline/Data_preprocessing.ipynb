# %%
# Import necessary libraries
import pymongo

# %%
# Connect to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["arabic_poems"]
collection = db["poems"]

# %%
# Print some sample data from MongoDB collection
for doc in collection.find().limit(5):  # Limiting to 5 documents for demonstration
    print(doc)
# Out:
# {'_id': ObjectId('6612d11df84fdf7786c45827'), 'date': 'الجمعة ٥ نيسان (أبريل) ٢٠٢٤', 'title': 'مبللة بالاشتياق', 'author': None, 'poem': 'كَانَ الفَصلُ شَغَفًا\nوَكَانتِ السَّاعةُ\nمُتجمِّدةَ عقاربِ العِناقِ\nنوافذُ القلبِ خلَّعَتْها\nأعَاصِيرُ اللوعَةِ\nسَتائرُ الرُّوحِ\nمِن دانتيلَ مُنقَّطٍ بِالخَيبةِ\nوَسَماءُ اللهفَةِ\nتُمطِرُ القُبُلاتِ بِحَرارةٍ\nلمْ أكُنْ أحمِلُ مِظَلَّةً تَقِيْني\nوابِلَ سِحرِكَ..\nلمْ أكُنْ ألبَسُ مِعطفًا\nيرُدُّ عنِّي زَمهرِيرَ الدَّهشةِ\nلمْ أكُنْ أنتعِلُ سِوى\nحِذاءِ الوقتِ المَثقوبِ!\nوَهُناكَ...\nعَلى قَارعةِ الانتِظارِ\nكُنتُ أرتجِفُ عِشقًا\nكُنتُ أقفُ مُبلَّلةً بِالاشتياقِ\nلا شَيءَ..\nلا صَوتَ..\nسِوَى زخَّاتِ نَبضٍ يَروي\nظَمَأَ الرُّوحِ القَاحلةِ\nمُنذُ عَهدِ المَجَاعةِ إلى الحُبِّ..\nقَوسُ قُزحِ بَهائِكَ\nهزَمَ عَتمةَ وحدَتِي\nجسَدَانِ..\nجسَدَانِ يُشعِلانِ حَطَبَ الوِصَالِ\nحتَّى انطِفاءِ لَهبِ الرَّغبةِ..\nفنجَانانِ مِن قَهوةِ الحُبِّ\nوبعضٌ مِن كَستَناءِ الفرَحِ\nزَادُ عاشِقَينِ\nحتَّى إشعارٍ آخرَ مِنَ العِنَاقِ!\nوَأمضِي..\nأتوكَّأُ حُزنِي\nرعدٌ.. وَبرقٌ.. وَليلٌ..\nيتكسَّرُ حِذائيَ البَلورِيَّ\nوأتعثَّرُ في خُطواتِ ظِلِّكَ المُسافرِ\nإلى محطَّاتِ الرَّجاءِ\nمطرٌ.. مطرٌ\nتتبلَّلُ أرصِفةَ الوَجدِ\nتنهمِرُ مزَاريبُ الذَّاكرةِ\nفَيهذي القلبُ:\n"كَانتْ لحظَاتٍ مِن يَاسمين\nلا يشمُّ عِطرَهَا\nإلَّا بُستانيٌّ بَارِعٌ فِي تَشذِيبِ الأمَانِي"\nمطَرٌ.. مطَرٌ\nسَنواتٌ مرَّتْ\nوأنا أعقِدُ رَبطةَ عُنُقِ الوقتِ\nأكوِي الأمَلَ المُجَعَّدَ\nوأزَرِّرُ قُمصَانَ غِيابِك\nسَنَواتٌ مَرَّتْ..\nوَأنَا أُطعِمُ عَصَافيرَ قَلبِي\nمِن قَمحِ الصَّبرِ\nوَأُهرِّبُ إليهَا\nالماءَ الصَّالِحَ لِلحُبِّ\nسنواتٌ مرَّتْ..\nوأنَا أُزركِشُ فَسَاتينَ قَصَائدي\nبِفَرَاشَاتِ الوَعدِ\nوأزرَعُ لهَا\nالوَردَ المُعرِّشَ عَلى جُدرَانِ رُوحِي\nسَنواتٌ مرَّتْ..\nومَازَالتِ الذَاكِرةُ مُصَابةً\nبِحُمَّى عِشقِكَ!\nسَنواتٌ مَرَّتْ..\nومَازالتِ الرُّوحُ تتذَكَّرُ\nأَنَّهَا التَقَتكَ\nعِندمَا كُنتَ تَعبُرُ\nإلَى الضِّفَّةِ الأُخرَى\nمِنَ الشِّعرِ!'}
# {'_id': ObjectId('6612d11df84fdf7786c45828'), 'date': 'الأحد ٧ نيسان (أبريل) ٢٠٢٤', 'title': 'لأرى الشاطئ الآخر', 'author': 'سفيان صلاح هلال رزق', 'poem': 'البحر\nكان أوَّل مُستقبِلٍ\nبعد آخر خطْوِي على اليابسةْ\nكان قبل وصولي\nيُلوِّحُ لي من بعيدٍ\nبأمواجهِ\nكان يقذفها عاليا\nفتعود إليه فأعرف أن مشيرا إليَّ\nيدل عليه\nينادي: " أنا في نتظارك يا صاحبي هاهنا"\nرحت أسعى بجد إليه\nورأسي تجيء إليَّ\nبعالمه المشتهى\nيتشكل ضد الرؤى البائسةْ\nكنت لا أتخيل أن مياهًا\nبلا آخرٍ\nكان ظني بأن جميع البحار\nكبحر يوسف بين الحقولِ\nيعيش أليفا\nله شاطئان\nوبعض العطايا\nوأسطورته\nحكمة هامسة\nلم أكن أدرك العمق فيه\nوضعفي\nوما كنت أدري بأني\nدخلت فصولا\nستمحو\nوتعطي\nوتثبت لونَ\nالسنين التي سوف تصبغ\nلحْظاتُها العيشة القادمةْ\n2- ضيافة\nأوقفني عاما\nيطعمني أسماكًا ميتةً\nيأسرني بالتشويقِ\nولا يدخلني في القصةِ\nحتى ثُرْتُ عليه\nوتعلمت العومَ\nالصيدَ\nالجرأةَ\nأرسل لي باخرة\nهل كنت أفكر في الناحية الأخرى\nويفكر لي\nفي تجربة أثرى\nتاه عليَّ بلؤلئهِ\nوغرائبهِ\nالموجة لا تحمل من قصصٍ\nما تحمله الأخرى\nونسيتُ عروسَ البحرِ\nبعرض البحِر\nوكانت في البرِّ خيالَ السهرةْ\nها قد صار البر خيالي\nوأطارد فيه بدل الموجِ\nحصانا\nأو كلبًا أو هرةْ\nها قد صار البحرُ حبيبي\nومنابعَ خوفي\nالبحرُ الآسرُ\nوالفاتنُ\nلا مخرج منه\nإلا برضاه\nأجري فوق السطحِ\nأغوص إلى القاعِ\nأريد بأن أبقى\nوأيضا\nأتلهف أن أتلاقى والبرَّ\n3- معاملة\nلا شيء إلا الريح في فضائهِ\nوالشمس\nفي سمائهِ وحيدةٌ\nوالأنجم التي كأنها سجينة الأماكنْ\nأين النساء\nوالعيال والجنائنْ\nأين الأماسي والعصاري\nوالمقاهي والمساكنْ\nأين عروس البحرِ\nأين السوقُ\nأين\nمعروض المعارضْ\nوفي كل الخطا نفس الروائحْ\nالماء وحده هنا\nهو الزمانُ\nوالأماكنْ\nوالموت أقرب المعارفْ\n4- جائزة\nلن تعبث بي يا بحرُ\nأنا البناء سليل نجومِ\nحضارات البشريةْ\nفي الظهر مسلَّةْ\nفي القلب مجرَّةْ\nما جئت إليك مصادفةً\nلا شك بأن لقائي بك\nفيه حلٌ لمشاكل إنسانيةْ\nهذا ما قلت لنفسي\nوأنا أتململ  من تكرار الأحداثِ\n/الأوقاتِ\n/نتائجِ رحلاتي فوق وتحت عوالم غيبيةْ\nكيف سأخرج يا بحرُ\nوأين تحط ُّ الرحلة بي\nوأنا التواق إلى الإشراقِ\nعلى الظلماتِ\nأجيء إليها\nبضياءٍ\nكلُّ الكون يراه\nوكأنَّ البحر أثارته نجوايَ\nفهاج الموج\nوعربدت الريحُ\nوراح الدرب من القبطانِ\nصرخت صراخ وليد في سَبَتٍ\nفي الأنواءِ\n: الله الله الله الله\nانفجر الفلكُ\nتجلى موتي في عينيَّ من الماءِ\nكررت ندائي\nارتدَّ الصوت اسْبحْ اسبح اسبحْ\nفسَبَحْتُ طويلا\nسَبَّحْتُ كثيرا\nحتى كاد الحال يهز يقيني\nإذ بالأمواج على صخر تلقي بي\nفأجدني في أرض أخرى\nليس بها إلا أنثى تتسيد فوق اليابس والماء'}
# {'_id': ObjectId('6612d11df84fdf7786c45829'), 'date': 'الأحد ٧ نيسان (أبريل) ٢٠٢٤', 'title': 'أقبلَ الصَّيفُ كئيبًا', 'author': None, 'poem': '(هذه القصيدة قديمة كتبتها في بداياتي الأولى وأنا لم أتجاوز ال 15 سنة من العمر..وقد أضفت لها بعض الأبيات الجديدة وأنشرها الآن لأول مرة)\nعُمرُنا يمضي خَبَبْ\nعيشُنا أضحَى صَخَبْ\nأقبلَ الصَّيفُ كئيبًا\nحاملا دمعَ التَّعَبْ\nقد بدَا اليأسُ بوجهٍ\nساطعٍ منهُ الغضَبْ\nواصفرارٌ وَشُحوبٌ\nوَهجيرٌ وَسَغَبْ\nساهِدٌ أضناهُ خطبٌ\nذابَ همًّا وَوَصَبْ\nإنَّ للصَّيفِ احتضارًا\nوَحياةً تُرتقَبْ\nتنضجُ الأثمارُ فيهِ\nمن نخيلٍ وَعنبْ\nينضجُ اليقطينُ والشَّمَّامُ\nيبدو كالذهبْ\nولياليهِ قصارٌ\nوبها يحلو الطرَبْ\nيسهرُ العُشَّاقُ فيها\nوَسيزدادُ العَتبْ\nيسطعُ البدرُ خلوبًا\nوَحيُ شعر وأدَبْ\nونجومٌ كالدّراري\nسرُّهَا كم يُحْتسَبْ\nلم تبُحْ عن أيِّ كُنهٍ\nهي تجري في خَببْ\nونرى البحرَ شرودًا\nوَبموج مُقتضَبْ\nهو عنوانُ حياةٍ\n... وَفناءٌ يُرتعَبْ\nأقبلَ الصيفً حزينا\nحاملا دمعِ التّعبْ\nحاملا دفئا وَحُبًّا\nلوجودٍ من لهبْ\nإنَ للصيفِ شجونًا\nووعودًا تُرتقبْ\nتكثرُ الرحلاتُ والنز\nهاتُ فيهِ تُطّلبْ\nلا غيومٌ لا سديمٌ\nلا نجومٌ تُحْتجَبْ\nوَيطولُ اللهوُ ثمَّ ال\nشّدْوُ من دونِ شَجَبْ\nفيهِ نزدادُ انطلاقا\nوالأماني تُنتدَبْ\nكلُّ مجدٍ بكفاح\nكلُّ نصر يُكتتبْ\nكلُّ يومٍ سوفَ نحياهُ\nليومٌ مُكتسَبْ\nكلُّ عشقٍ عفويٍّ\nزائرٌ دون سَبَبْ\nكلٌّ حقٍّ سوفَ يعلو\nكانَ دومًا مُنتهَبْ\nكلُّ مجهولٍ سيأتي\nونرى فيه العجَبْ\nنحنُ في الدنيا كطيفٍ\nكلُّنا نفسُ المَطبْ\nنحنُ للتُّربِ نزولٌ\nستُوارينا التُّرَبْ\nإنّما الروحُ ستحيا\nوَجسُومٌ للعطبْ\nإنَّ روحي في سُمُوٍّ\nفوقَ كون من شَغَبْ\nلا أريدُ الأرضَ دارًا\nجنَّةُ الخُلدِ الأرَبْ\nأنا أحيا في بلادٍ\nوأراني مُغترَبْ\nنابضٌ بالحُبِّ قلبي\nوالمُنى لم تُسْتَجَبْ\nإنَّني غرِّيدُ شعبي\nصرحُ فنٍّ وَخُطب\nشاعر الأوطانِ قالوا\nإنهُ نعمَ اللقبْ\nخالدٌ شعري ويبقى\nهُوَ ديوانَ العَرَبْ\nإنَّني النهرُ عطاءً\nدفقُ فنِّي ما نضَبْ\nنزفُ قلبي كلَّ حُبٍّ\nوَحُبور قد وَهَبْ\nإنّني رمزُ كفاح\nوليَ المجدُ انتسَبْ\nإنَّني مع كلِّ مظلومٍ\nوَشعبٍ يُنتكَبْ\nشبحُ الموتِ تلاشى\nهُوَ منِّي قد هرَبْ\nكم ورودٍ هي تذوي\nوحُقوق تُغتصَبْ\nرحلَ العدلُ وغابَ ال\nسلمُ وأرضٌ تُنتهَبْ\nوأرى في كلِّ رُكنٍ\nشبحَ الموتِ انتصَبْ\nواقعٌ صعبٌ أليمٌ\nقالَ هذا ما كذبْ\nلم يُجَسِّدْهُ كلامٌ\nوَبشعر أو خُطبْ\nفتلاشى كلُّ خير\nكلُّ أمر انقلبْ\nوغدا المَسْخُ زعيمًا\nأصبحَ الرأسَ الذنبْ\nأصبحَ اليومِ أديبًا\nكلُّ من هبَّ وَدَبْ\nونوادي الإفكِ تبقى\nللمخازي تُنتخَبْ\nأكرمُوا كلَّ وضيع\nكلَّ مسخ مُجْتنَبْ\nأبلهٍ يخلطُ شَعْبانَ\nبحُمق مع رَجَبْ\nوحمارٍ يرفعُ المَجْ\nزومَ ... والجرَّ نصَبْ\nعالمٌ أضحى جحيمًا\nشرقُهُ أمسى كغربْ\nحولنا الشرُّ ..غرابُ ال\nبينِ فينا قد نعَبْ\nوالسّواقي في وُجومٍ\nطائرُ الشَّوقِ انتحَبْ\nكم جحيم قد عبرنا\n... وعلينا قد وَجَبْ\nرغم عسفِ الليلِ يبقى\nكلُّ حلمْ مُرتقبْ\nرغم أهوالِ الدياجي\nموعدُ الفجرِ اقتربْ\nوغدًا يندحرُ الشَّرُّ\nوينزاحُ الكرب\nيتلاشى كلُّ ظلمٍ\nرغمَ أسوارِ اللهَبْ\nوَنرى النورَ تهادى\nونرى الليلَ انسَحَبْ'}
# {'_id': ObjectId('6612d11df84fdf7786c4582a'), 'date': 'الاثنين ١٠ نيسان (أبريل) ٢٠٢٣', 'title': 'شَوْقٌ', 'author': None, 'poem': 'شَــوْقٌ\nوَأَشْتَاقُ حُلْوَ الغَمَامْ.\nإِلَى سَوْرَةِ  الـحُبِّ يَهْفُو جُنُونِـي.\nإِلَى الأَرَقِ الدَّامِعِ العَيْنِ أَهْفُو.\nإِلَى لَـهَبِ الغَيْرَةِ الطَّائِشَهْ\nتَقُضُّ الـحَشَى  وَتُقِيمُ ظُنُونِـي،\nيَتُوقُ فُؤَادِي الـمُعَنَّى  الـحُطَامْ.\nأَتُوقُ عَذَابَ الـجَحِيمِ، وَأَقْفُو\nسَبِيلَ الـحَيَارَى السُّكَارَى السِّقَامْ .\nوَأَشْتَاقُ غَيْثًا مُغِيثًا كَنَزْفِ العُيُونِ.\nوَأَشْتَاقُ.. فَيْضَ الـهُيَامْ .\nفوزيّة الشّطّي\nتونس: 2023.3.18'}
# {'_id': ObjectId('6612d11df84fdf7786c4582b'), 'date': 'الأحد ٧ نيسان (أبريل) ٢٠٢٤', 'title': 'لا تدمن', 'author': None, 'poem': 'ماذا عسايَ بأنْ أقولَ لمدمنٍ\nفقدَ الصوابَ وباتَ يحجبُ عقلهُ\nويظلُّ يسرفُ في التعاطي دائمًا\nلم يَعتَبِرْ بضياعِ جيلٍ قبلهُ\nقد أخطأَ المسكينُ عِنْدَ قبولِهِ\nلنصيحةِ الشَّيْطَانِ يعصي مثلَهُ\nيا صاحبي إنّي إليك لناصحٌ\nمن يدمنِ الأضرارَ يفقدْ مالهُ\nوكذا يزولُ العقلُ بعدَ رجاحةٍ\nوترى الشرورَ ينالها مَنْ حولَهُ\nأدرك خطورة ما تقومُ بفعلِهِ\nوتجنّبِ الإدمانَ وارفضْ ذُلَّهُ\nإنّي أريدُك أن تكونَ ملازمًا\nلعبادة الرَّحْمَنِ تكسِبُ وصلهُ\nوسؤالُكَ المنّانَ تلكَ عبادَةٌ\nمن يسأَلِ الرحمنَ يُعْطَ سُؤَالَهُ\nفاخْتَرْ صديقك واصطفيهِ تفاخرًا\nفالخلُّ ينفعُ في القيامةِ خلَّهُ\nهذِى النصائِحُ إن أردتَ فخذْ بها\nواتركْ طريقَ الذلِّ لا تٌسلمْ لَهُ'}

# %%
# Text Cleaning
import re

def clean_text(text):
    # Remove punctuation and special characters from the original text
    cleaned_text = re.sub(r'[^\w\s\u0600-\u06FF]', '', text)  # Include Arabic Unicode range \u0600-\u06FF
    # Remove digits from the cleaned text
    cleaned_text = re.sub(r'\d+', '', cleaned_text)
    # Remove line breaks from the cleaned text
    cleaned_text = cleaned_text.replace('\n', '. ')
    return cleaned_text

# Fetch data from MongoDB and perform text cleaning
cleaned_data = []
for doc in collection.find({}, {"_id": 0, "poem": 1}):  # Iterate over documents and retrieve "poem" field
    text = doc.get("poem", "")  # Extract text (poem) from the document
    cleaned_text = clean_text(text)  # Clean the text
    cleaned_data.append(cleaned_text)  # Append cleaned text to the list

# Print cleaned data (you may want to explore the data first to decide if cleaning is needed)
print(cleaned_data[:5])  # Print first 5 cleaned poems
# Out:
# ['كَانَ الفَصلُ شَغَفًا. وَكَانتِ السَّاعةُ. مُتجمِّدةَ عقاربِ العِناقِ. نوافذُ القلبِ خلَّعَتْها. أعَاصِيرُ اللوعَةِ. سَتائرُ الرُّوحِ. مِن دانتيلَ مُنقَّطٍ بِالخَيبةِ. وَسَماءُ اللهفَةِ. تُمطِرُ القُبُلاتِ بِحَرارةٍ. لمْ أكُنْ أحمِلُ مِظَلَّةً تَقِيْني. وابِلَ سِحرِكَ. لمْ أكُنْ ألبَسُ مِعطفًا. يرُدُّ عنِّي زَمهرِيرَ الدَّهشةِ. لمْ أكُنْ أنتعِلُ سِوى. حِذاءِ الوقتِ المَثقوبِ. وَهُناكَ. عَلى قَارعةِ الانتِظارِ. كُنتُ أرتجِفُ عِشقًا. كُنتُ أقفُ مُبلَّلةً بِالاشتياقِ. لا شَيءَ. لا صَوتَ. سِوَى زخَّاتِ نَبضٍ يَروي. ظَمَأَ الرُّوحِ القَاحلةِ. مُنذُ عَهدِ المَجَاعةِ إلى الحُبِّ. قَوسُ قُزحِ بَهائِكَ. هزَمَ عَتمةَ وحدَتِي. جسَدَانِ. جسَدَانِ يُشعِلانِ حَطَبَ الوِصَالِ. حتَّى انطِفاءِ لَهبِ الرَّغبةِ. فنجَانانِ مِن قَهوةِ الحُبِّ. وبعضٌ مِن كَستَناءِ الفرَحِ. زَادُ عاشِقَينِ. حتَّى إشعارٍ آخرَ مِنَ العِنَاقِ. وَأمضِي. أتوكَّأُ حُزنِي. رعدٌ وَبرقٌ وَليلٌ. يتكسَّرُ حِذائيَ البَلورِيَّ. وأتعثَّرُ في خُطواتِ ظِلِّكَ المُسافرِ. إلى محطَّاتِ الرَّجاءِ. مطرٌ مطرٌ. تتبلَّلُ أرصِفةَ الوَجدِ. تنهمِرُ مزَاريبُ الذَّاكرةِ. فَيهذي القلبُ. كَانتْ لحظَاتٍ مِن يَاسمين. لا يشمُّ عِطرَهَا. إلَّا بُستانيٌّ بَارِعٌ فِي تَشذِيبِ الأمَانِي. مطَرٌ مطَرٌ. سَنواتٌ مرَّتْ. وأنا أعقِدُ رَبطةَ عُنُقِ الوقتِ. أكوِي الأمَلَ المُجَعَّدَ. وأزَرِّرُ قُمصَانَ غِيابِك. سَنَواتٌ مَرَّتْ. وَأنَا أُطعِمُ عَصَافيرَ قَلبِي. مِن قَمحِ الصَّبرِ. وَأُهرِّبُ إليهَا. الماءَ الصَّالِحَ لِلحُبِّ. سنواتٌ مرَّتْ. وأنَا أُزركِشُ فَسَاتينَ قَصَائدي. بِفَرَاشَاتِ الوَعدِ. وأزرَعُ لهَا. الوَردَ المُعرِّشَ عَلى جُدرَانِ رُوحِي. سَنواتٌ مرَّتْ. ومَازَالتِ الذَاكِرةُ مُصَابةً. بِحُمَّى عِشقِكَ. سَنواتٌ مَرَّتْ. ومَازالتِ الرُّوحُ تتذَكَّرُ. أَنَّهَا التَقَتكَ. عِندمَا كُنتَ تَعبُرُ. إلَى الضِّفَّةِ الأُخرَى. مِنَ الشِّعرِ', 'البحر. كان أوَّل مُستقبِلٍ. بعد آخر خطْوِي على اليابسةْ. كان قبل وصولي. يُلوِّحُ لي من بعيدٍ. بأمواجهِ. كان يقذفها عاليا. فتعود إليه فأعرف أن مشيرا إليَّ. يدل عليه. ينادي  أنا في نتظارك يا صاحبي هاهنا. رحت أسعى بجد إليه. ورأسي تجيء إليَّ. بعالمه المشتهى. يتشكل ضد الرؤى البائسةْ. كنت لا أتخيل أن مياهًا. بلا آخرٍ. كان ظني بأن جميع البحار. كبحر يوسف بين الحقولِ. يعيش أليفا. له شاطئان. وبعض العطايا. وأسطورته. حكمة هامسة. لم أكن أدرك العمق فيه. وضعفي. وما كنت أدري بأني. دخلت فصولا. ستمحو. وتعطي. وتثبت لونَ. السنين التي سوف تصبغ. لحْظاتُها العيشة القادمةْ.  ضيافة. أوقفني عاما. يطعمني أسماكًا ميتةً. يأسرني بالتشويقِ. ولا يدخلني في القصةِ. حتى ثُرْتُ عليه. وتعلمت العومَ. الصيدَ. الجرأةَ. أرسل لي باخرة. هل كنت أفكر في الناحية الأخرى. ويفكر لي. في تجربة أثرى. تاه عليَّ بلؤلئهِ. وغرائبهِ. الموجة لا تحمل من قصصٍ. ما تحمله الأخرى. ونسيتُ عروسَ البحرِ. بعرض البحِر. وكانت في البرِّ خيالَ السهرةْ. ها قد صار البر خيالي. وأطارد فيه بدل الموجِ. حصانا. أو كلبًا أو هرةْ. ها قد صار البحرُ حبيبي. ومنابعَ خوفي. البحرُ الآسرُ. والفاتنُ. لا مخرج منه. إلا برضاه. أجري فوق السطحِ. أغوص إلى القاعِ. أريد بأن أبقى. وأيضا. أتلهف أن أتلاقى والبرَّ.  معاملة. لا شيء إلا الريح في فضائهِ. والشمس. في سمائهِ وحيدةٌ. والأنجم التي كأنها سجينة الأماكنْ. أين النساء. والعيال والجنائنْ. أين الأماسي والعصاري. والمقاهي والمساكنْ. أين عروس البحرِ. أين السوقُ. أين. معروض المعارضْ. وفي كل الخطا نفس الروائحْ. الماء وحده هنا. هو الزمانُ. والأماكنْ. والموت أقرب المعارفْ.  جائزة. لن تعبث بي يا بحرُ. أنا البناء سليل نجومِ. حضارات البشريةْ. في الظهر مسلَّةْ. في القلب مجرَّةْ. ما جئت إليك مصادفةً. لا شك بأن لقائي بك. فيه حلٌ لمشاكل إنسانيةْ. هذا ما قلت لنفسي. وأنا أتململ  من تكرار الأحداثِ. الأوقاتِ. نتائجِ رحلاتي فوق وتحت عوالم غيبيةْ. كيف سأخرج يا بحرُ. وأين تحط ُّ الرحلة بي. وأنا التواق إلى الإشراقِ. على الظلماتِ. أجيء إليها. بضياءٍ. كلُّ الكون يراه. وكأنَّ البحر أثارته نجوايَ. فهاج الموج. وعربدت الريحُ. وراح الدرب من القبطانِ. صرخت صراخ وليد في سَبَتٍ. في الأنواءِ.  الله الله الله الله. انفجر الفلكُ. تجلى موتي في عينيَّ من الماءِ. كررت ندائي. ارتدَّ الصوت اسْبحْ اسبح اسبحْ. فسَبَحْتُ طويلا. سَبَّحْتُ كثيرا. حتى كاد الحال يهز يقيني. إذ بالأمواج على صخر تلقي بي. فأجدني في أرض أخرى. ليس بها إلا أنثى تتسيد فوق اليابس والماء', 'هذه القصيدة قديمة كتبتها في بداياتي الأولى وأنا لم أتجاوز ال  سنة من العمروقد أضفت لها بعض الأبيات ...

# %%
# Tokenization
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# Tokenize phrases into words
tokenized_words = []
for poem in cleaned_data:
    phrases = sent_tokenize(poem)
    for phrase in phrases:
        words = word_tokenize(phrase.rstrip('.'))
        tokenized_words.append(words)

# Print the tokenized words for the first few phrases
for i, words in enumerate(tokenized_words[:100]):
    print(f"Phrase {i+1} words:", words)
# Out:
# Phrase 1 words: ['كَانَ', 'الفَصلُ', 'شَغَفًا']
# Phrase 2 words: ['وَكَانتِ', 'السَّاعةُ']
# Phrase 3 words: ['مُتجمِّدةَ', 'عقاربِ', 'العِناقِ']
# Phrase 4 words: ['نوافذُ', 'القلبِ', 'خلَّعَتْها']
# Phrase 5 words: ['أعَاصِيرُ', 'اللوعَةِ']
# Phrase 6 words: ['سَتائرُ', 'الرُّوحِ']
# Phrase 7 words: ['مِن', 'دانتيلَ', 'مُنقَّطٍ', 'بِالخَيبةِ']
# Phrase 8 words: ['وَسَماءُ', 'اللهفَةِ']
# Phrase 9 words: ['تُمطِرُ', 'القُبُلاتِ', 'بِحَرارةٍ']
# Phrase 10 words: ['لمْ', 'أكُنْ', 'أحمِلُ', 'مِظَلَّةً', 'تَقِيْني']
# Phrase 11 words: ['وابِلَ', 'سِحرِكَ']
# Phrase 12 words: ['لمْ', 'أكُنْ', 'ألبَسُ', 'مِعطفًا']
# Phrase 13 words: ['يرُدُّ', 'عنِّي', 'زَمهرِيرَ', 'الدَّهشةِ']
# Phrase 14 words: ['لمْ', 'أكُنْ', 'أنتعِلُ', 'سِوى']
# Phrase 15 words: ['حِذاءِ', 'الوقتِ', 'المَثقوبِ']
# Phrase 16 words: ['وَهُناكَ']
# Phrase 17 words: ['عَلى', 'قَارعةِ', 'الانتِظارِ']
# Phrase 18 words: ['كُنتُ', 'أرتجِفُ', 'عِشقًا']
# Phrase 19 words: ['كُنتُ', 'أقفُ', 'مُبلَّلةً', 'بِالاشتياقِ']
# Phrase 20 words: ['لا', 'شَيءَ']
# Phrase 21 words: ['لا', 'صَوتَ']
# Phrase 22 words: ['سِوَى', 'زخَّاتِ', 'نَبضٍ', 'يَروي']
# Phrase 23 words: ['ظَمَأَ', 'الرُّوحِ', 'القَاحلةِ']
# Phrase 24 words: ['مُنذُ', 'عَهدِ', 'المَجَاعةِ', 'إلى', 'الحُبِّ']
# Phrase 25 words: ['قَوسُ', 'قُزحِ', 'بَهائِكَ']
# Phrase 26 words: ['هزَمَ', 'عَتمةَ', 'وحدَتِي']
# Phrase 27 words: ['جسَدَانِ']
# Phrase 28 words: ['جسَدَانِ', 'يُشعِلانِ', 'حَطَبَ', 'الوِصَالِ']
# Phrase 29 words: ['حتَّى', 'انطِفاءِ', 'لَهبِ', 'الرَّغبةِ']
# Phrase 30 words: ['فنجَانانِ', 'مِن', 'قَهوةِ', 'الحُبِّ']
# Phrase 31 words: ['وبعضٌ', 'مِن', 'كَستَناءِ', 'الفرَحِ']
# Phrase 32 words: ['زَادُ', 'عاشِقَينِ']
# Phrase 33 words: ['حتَّى', 'إشعارٍ', 'آخرَ', 'مِنَ', 'العِنَاقِ']
# Phrase 34 words: ['وَأمضِي']
# Phrase 35 words: ['أتوكَّأُ', 'حُزنِي']
# Phrase 36 words: ['رعدٌ', 'وَبرقٌ', 'وَليلٌ']
# Phrase 37 words: ['يتكسَّرُ', 'حِذائيَ', 'البَلورِيَّ']
# Phrase 38 words: ['وأتعثَّرُ', 'في', 'خُطواتِ', 'ظِلِّكَ', 'المُسافرِ']
# Phrase 39 words: ['إلى', 'محطَّاتِ', 'الرَّجاءِ']
# Phrase 40 words: ['مطرٌ', 'مطرٌ']
# Phrase 41 words: ['تتبلَّلُ', 'أرصِفةَ', 'الوَجدِ']
# Phrase 42 words: ['تنهمِرُ', 'مزَاريبُ', 'الذَّاكرةِ']
# Phrase 43 words: ['فَيهذي', 'القلبُ']
# Phrase 44 words: ['كَانتْ', 'لحظَاتٍ', 'مِن', 'يَاسمين']
# Phrase 45 words: ['لا', 'يشمُّ', 'عِطرَهَا']
# Phrase 46 words: ['إلَّا', 'بُستانيٌّ', 'بَارِعٌ', 'فِي', 'تَشذِيبِ', 'الأمَانِي']
# Phrase 47 words: ['مطَرٌ', 'مطَرٌ']
# Phrase 48 words: ['سَنواتٌ', 'مرَّتْ']
# Phrase 49 words: ['وأنا', 'أعقِدُ', 'رَبطةَ', 'عُنُقِ', 'الوقتِ']
# Phrase 50 words: ['أكوِي', 'الأمَلَ', 'المُجَعَّدَ']
# Phrase 51 words: ['وأزَرِّرُ', 'قُمصَانَ', 'غِيابِك']
# Phrase 52 words: ['سَنَواتٌ', 'مَرَّتْ']
# Phrase 53 words: ['وَأنَا', 'أُطعِمُ', 'عَصَافيرَ', 'قَلبِي']
# Phrase 54 words: ['مِن', 'قَمحِ', 'الصَّبرِ']
# Phrase 55 words: ['وَأُهرِّبُ', 'إليهَا']
# Phrase 56 words: ['الماءَ', 'الصَّالِحَ', 'لِلحُبِّ']
# Phrase 57 words: ['سنواتٌ', 'مرَّتْ']
# Phrase 58 words: ['وأنَا', 'أُزركِشُ', 'فَسَاتينَ', 'قَصَائدي']
# Phrase 59 words: ['بِفَرَاشَاتِ', 'الوَعدِ']
# Phrase 60 words: ['وأزرَعُ', 'لهَا']
# Phrase 61 words: ['الوَردَ', 'المُعرِّشَ', 'عَلى', 'جُدرَانِ', 'رُوحِي']
# Phrase 62 words: ['سَنواتٌ', 'مرَّتْ']
# Phrase 63 words: ['ومَازَالتِ', 'الذَاكِرةُ', 'مُصَابةً']
# Phrase 64 words: ['بِحُمَّى', 'عِشقِكَ']
# Phrase 65 words: ['سَنواتٌ', 'مَرَّتْ']
# Phrase 66 words: ['ومَازالتِ', 'الرُّوحُ', 'تتذَكَّرُ']
# Phrase 67 words: ['أَنَّهَا', 'التَقَتكَ']
# Phrase 68 words: ['عِندمَا', 'كُنتَ', 'تَعبُرُ']
# Phrase 69 words: ['إلَى', 'الضِّفَّةِ', 'الأُخرَى']
# Phrase 70 words: ['مِنَ', 'الشِّعرِ']
# Phrase 71 words: ['البحر']
# Phrase 72 words: ['كان', 'أوَّل', 'مُستقبِلٍ']
# Phrase 73 words: ['بعد', 'آخر', 'خطْوِي', 'على', 'اليابسةْ']
# Phrase 74 words: ['كان', 'قبل', 'وصولي']
# Phrase 75 words: ['يُلوِّحُ', 'لي', 'من', 'بعيدٍ']
# Phrase 76 words: ['بأمواجهِ']
# Phrase 77 words: ['كان', 'يقذفها', 'عاليا']
# Phrase 78 words: ['فتعود', 'إليه', 'فأعرف', 'أن', 'مشيرا', 'إليَّ']
# Phrase 79 words: ['يدل', 'عليه']
# Phrase 80 words: ['ينادي', 'أنا', 'في', 'نتظارك', 'يا', 'صاحبي', 'هاهنا']
# Phrase 81 words: ['رحت', 'أسعى', 'بجد', 'إليه']
# Phrase 82 words: ['ورأسي', 'تجيء', 'إليَّ']
# Phrase 83 words: ['بعالمه', 'المشتهى']
# Phrase 84 words: ['يتشكل', 'ضد', 'الرؤى', 'البائسةْ']
# Phrase 85 words: ['كنت', 'لا', 'أتخيل', 'أن', 'مياهًا']
# Phrase 86 words: ['بلا', 'آخرٍ']
# Phrase 87 words: ['كان', 'ظني', 'بأن', 'جميع', 'البحار']
# Phrase 88 words: ['كبحر', 'يوسف', 'بين', 'الحقولِ']
# Phrase 89 words: ['يعيش', 'أليفا']
# Phrase 90 words: ['له', 'شاطئان']
# Phrase 91 words: ['وبعض', 'العطايا']
# Phrase 92 words: ['وأسطورته']
# Phrase 93 words: ['حكمة', 'هامسة']
# Phrase 94 words: ['لم', 'أكن', 'أدرك', 'العمق', 'فيه']
# Phrase 95 words: ['وضعفي']
# Phrase 96 words: ['وما', 'كنت', 'أدري', 'بأني']
# Phrase 97 words: ['دخلت', 'فصولا']
# Phrase 98 words: ['ستمحو']
# Phrase 99 words: ['وتعطي']
# Phrase 100 words: ['وتثبت', 'لونَ']

# %%
# Stop words
from nltk.corpus import stopwords

# Function to remove stop words from a list of words
def remove_stopwords(words):
    return [word for word in words if word.lower() not in stopwords.words('arabic')]

# Remove stop words from tokenized words
filtered_words = [remove_stopwords(words) for words in tokenized_words]

# Print the filtered words
for i, words in enumerate(filtered_words[:100]):  # Print the first few phrases
    print(f"Phrase {i+1} words (without stop words):", words)
# Out:
# Phrase 1 words (without stop words): ['كَانَ', 'الفَصلُ', 'شَغَفًا']
# Phrase 2 words (without stop words): ['وَكَانتِ', 'السَّاعةُ']
# Phrase 3 words (without stop words): ['مُتجمِّدةَ', 'عقاربِ', 'العِناقِ']
# Phrase 4 words (without stop words): ['نوافذُ', 'القلبِ', 'خلَّعَتْها']
# Phrase 5 words (without stop words): ['أعَاصِيرُ', 'اللوعَةِ']
# Phrase 6 words (without stop words): ['سَتائرُ', 'الرُّوحِ']
# Phrase 7 words (without stop words): ['مِن', 'دانتيلَ', 'مُنقَّطٍ', 'بِالخَيبةِ']
# Phrase 8 words (without stop words): ['وَسَماءُ', 'اللهفَةِ']
# Phrase 9 words (without stop words): ['تُمطِرُ', 'القُبُلاتِ', 'بِحَرارةٍ']
# Phrase 10 words (without stop words): ['لمْ', 'أكُنْ', 'أحمِلُ', 'مِظَلَّةً', 'تَقِيْني']
# Phrase 11 words (without stop words): ['وابِلَ', 'سِحرِكَ']
# Phrase 12 words (without stop words): ['لمْ', 'أكُنْ', 'ألبَسُ', 'مِعطفًا']
# Phrase 13 words (without stop words): ['يرُدُّ', 'عنِّي', 'زَمهرِيرَ', 'الدَّهشةِ']
# Phrase 14 words (without stop words): ['لمْ', 'أكُنْ', 'أنتعِلُ', 'سِوى']
# Phrase 15 words (without stop words): ['حِذاءِ', 'الوقتِ', 'المَثقوبِ']
# Phrase 16 words (without stop words): ['وَهُناكَ']
# Phrase 17 words (without stop words): ['عَلى', 'قَارعةِ', 'الانتِظارِ']
# Phrase 18 words (without stop words): ['كُنتُ', 'أرتجِفُ', 'عِشقًا']
# Phrase 19 words (without stop words): ['كُنتُ', 'أقفُ', 'مُبلَّلةً', 'بِالاشتياقِ']
# Phrase 20 words (without stop words): ['شَيءَ']
# Phrase 21 words (without stop words): ['صَوتَ']
# Phrase 22 words (without stop words): ['سِوَى', 'زخَّاتِ', 'نَبضٍ', 'يَروي']
# Phrase 23 words (without stop words): ['ظَمَأَ', 'الرُّوحِ', 'القَاحلةِ']
# Phrase 24 words (without stop words): ['مُنذُ', 'عَهدِ', 'المَجَاعةِ', 'الحُبِّ']
# Phrase 25 words (without stop words): ['قَوسُ', 'قُزحِ', 'بَهائِكَ']
# Phrase 26 words (without stop words): ['هزَمَ', 'عَتمةَ', 'وحدَتِي']
# Phrase 27 words (without stop words): ['جسَدَانِ']
# Phrase 28 words (without stop words): ['جسَدَانِ', 'يُشعِلانِ', 'حَطَبَ', 'الوِصَالِ']
# Phrase 29 words (without stop words): ['حتَّى', 'انطِفاءِ', 'لَهبِ', 'الرَّغبةِ']
# Phrase 30 words (without stop words): ['فنجَانانِ', 'مِن', 'قَهوةِ', 'الحُبِّ']
# Phrase 31 words (without stop words): ['وبعضٌ', 'مِن', 'كَستَناءِ', 'الفرَحِ']
# Phrase 32 words (without stop words): ['زَادُ', 'عاشِقَينِ']
# Phrase 33 words (without stop words): ['حتَّى', 'إشعارٍ', 'آخرَ', 'مِنَ', 'العِنَاقِ']
# Phrase 34 words (without stop words): ['وَأمضِي']
# Phrase 35 words (without stop words): ['أتوكَّأُ', 'حُزنِي']
# Phrase 36 words (without stop words): ['رعدٌ', 'وَبرقٌ', 'وَليلٌ']
# Phrase 37 words (without stop words): ['يتكسَّرُ', 'حِذائيَ', 'البَلورِيَّ']
# Phrase 38 words (without stop words): ['وأتعثَّرُ', 'خُطواتِ', 'ظِلِّكَ', 'المُسافرِ']
# Phrase 39 words (without stop words): ['محطَّاتِ', 'الرَّجاءِ']
# Phrase 40 words (without stop words): ['مطرٌ', 'مطرٌ']
# Phrase 41 words (without stop words): ['تتبلَّلُ', 'أرصِفةَ', 'الوَجدِ']
# Phrase 42 words (without stop words): ['تنهمِرُ', 'مزَاريبُ', 'الذَّاكرةِ']
# Phrase 43 words (without stop words): ['فَيهذي', 'القلبُ']
# Phrase 44 words (without stop words): ['كَانتْ', 'لحظَاتٍ', 'مِن', 'يَاسمين']
# Phrase 45 words (without stop words): ['يشمُّ', 'عِطرَهَا']
# Phrase 46 words (without stop words): ['إلَّا', 'بُستانيٌّ', 'بَارِعٌ', 'فِي', 'تَشذِيبِ', 'الأمَانِي']
# Phrase 47 words (without stop words): ['مطَرٌ', 'مطَرٌ']
# Phrase 48 words (without stop words): ['سَنواتٌ', 'مرَّتْ']
# Phrase 49 words (without stop words): ['وأنا', 'أعقِدُ', 'رَبطةَ', 'عُنُقِ', 'الوقتِ']
# Phrase 50 words (without stop words): ['أكوِي', 'الأمَلَ', 'المُجَعَّدَ']
# Phrase 51 words (without stop words): ['وأزَرِّرُ', 'قُمصَانَ', 'غِيابِك']
# Phrase 52 words (without stop words): ['سَنَواتٌ', 'مَرَّتْ']
# Phrase 53 words (without stop words): ['وَأنَا', 'أُطعِمُ', 'عَصَافيرَ', 'قَلبِي']
# Phrase 54 words (without stop words): ['مِن', 'قَمحِ', 'الصَّبرِ']
# Phrase 55 words (without stop words): ['وَأُهرِّبُ', 'إليهَا']
# Phrase 56 words (without stop words): ['الماءَ', 'الصَّالِحَ', 'لِلحُبِّ']
# Phrase 57 words (without stop words): ['سنواتٌ', 'مرَّتْ']
# Phrase 58 words (without stop words): ['وأنَا', 'أُزركِشُ', 'فَسَاتينَ', 'قَصَائدي']
# Phrase 59 words (without stop words): ['بِفَرَاشَاتِ', 'الوَعدِ']
# Phrase 60 words (without stop words): ['وأزرَعُ', 'لهَا']
# Phrase 61 words (without stop words): ['الوَردَ', 'المُعرِّشَ', 'عَلى', 'جُدرَانِ', 'رُوحِي']
# Phrase 62 words (without stop words): ['سَنواتٌ', 'مرَّتْ']
# Phrase 63 words (without stop words): ['ومَازَالتِ', 'الذَاكِرةُ', 'مُصَابةً']
# Phrase 64 words (without stop words): ['بِحُمَّى', 'عِشقِكَ']
# Phrase 65 words (without stop words): ['سَنواتٌ', 'مَرَّتْ']
# Phrase 66 words (without stop words): ['ومَازالتِ', 'الرُّوحُ', 'تتذَكَّرُ']
# Phrase 67 words (without stop words): ['أَنَّهَا', 'التَقَتكَ']
# Phrase 68 words (without stop words): ['عِندمَا', 'كُنتَ', 'تَعبُرُ']
# Phrase 69 words (without stop words): ['إلَى', 'الضِّفَّةِ', 'الأُخرَى']
# Phrase 70 words (without stop words): ['مِنَ', 'الشِّعرِ']
# Phrase 71 words (without stop words): ['البحر']
# Phrase 72 words (without stop words): ['أوَّل', 'مُستقبِلٍ']
# Phrase 73 words (without stop words): ['آخر', 'خطْوِي', 'اليابسةْ']
# Phrase 74 words (without stop words): ['وصولي']
# Phrase 75 words (without stop words): ['يُلوِّحُ', 'بعيدٍ']
# Phrase 76 words (without stop words): ['بأمواجهِ']
# Phrase 77 words (without stop words): ['يقذفها', 'عاليا']
# Phrase 78 words (without stop words): ['فتعود', 'إليه', 'فأعرف', 'مشيرا', 'إليَّ']
# Phrase 79 words (without stop words): ['يدل']
# Phrase 80 words (without stop words): ['ينادي', 'نتظارك', 'صاحبي']
# Phrase 81 words (without stop words): ['رحت', 'أسعى', 'بجد', 'إليه']
# Phrase 82 words (without stop words): ['ورأسي', 'تجيء', 'إليَّ']
# Phrase 83 words (without stop words): ['بعالمه', 'المشتهى']
# Phrase 84 words (without stop words): ['يتشكل', 'ضد', 'الرؤى', 'البائسةْ']
# Phrase 85 words (without stop words): ['كنت', 'أتخيل', 'مياهًا']
# Phrase 86 words (without stop words): ['بلا', 'آخرٍ']
# Phrase 87 words (without stop words): ['ظني', 'بأن', 'البحار']
# Phrase 88 words (without stop words): ['كبحر', 'يوسف', 'الحقولِ']
# Phrase 89 words (without stop words): ['يعيش', 'أليفا']
# Phrase 90 words (without stop words): ['شاطئان']
# Phrase 91 words (without stop words): ['وبعض', 'العطايا']
# Phrase 92 words (without stop words): ['وأسطورته']
# Phrase 93 words (without stop words): ['حكمة', 'هامسة']
# Phrase 94 words (without stop words): ['أكن', 'أدرك', 'العمق']
# Phrase 95 words (without stop words): ['وضعفي']
# Phrase 96 words (without stop words): ['كنت', 'أدري', 'بأني']
# Phrase 97 words (without stop words): ['دخلت', 'فصولا']
# Phrase 98 words (without stop words): ['ستمحو']
# Phrase 99 words (without stop words): ['وتعطي']
# Phrase 100 words (without stop words): ['وتثبت', 'لونَ']

# %%
# Removing diacritics
def remove_diacritics(word_or_list):
    # Define a regular expression pattern to match Arabic diacritics
    pattern = r'[\u064B-\u065F\u0670]'  # Range of Arabic diacritical marks
    
    # If input is a list, apply remove_diacritics recursively to each element
    if isinstance(word_or_list, list):
        return [remove_diacritics(word) for word in word_or_list]
    
    # If input is a string, remove diacritics using the pattern
    elif isinstance(word_or_list, str):
        return re.sub(pattern, '', word_or_list)
    
    # Otherwise, return the input unchanged
    else:
        return word_or_list

# Apply remove_diacritics function to filtered_words
cleaned_words = remove_diacritics(filtered_words)

# Print words without diacritics
for i, words in enumerate(cleaned_words[:100]):  # Print the first few phrases
    print(f"Phrase {i+1} words (without diacritics):", words)
# Out:
# Phrase 1 words (without diacritics): ['كان', 'الفصل', 'شغفا']
# Phrase 2 words (without diacritics): ['وكانت', 'الساعة']
# Phrase 3 words (without diacritics): ['متجمدة', 'عقارب', 'العناق']
# Phrase 4 words (without diacritics): ['نوافذ', 'القلب', 'خلعتها']
# Phrase 5 words (without diacritics): ['أعاصير', 'اللوعة']
# Phrase 6 words (without diacritics): ['ستائر', 'الروح']
# Phrase 7 words (without diacritics): ['من', 'دانتيل', 'منقط', 'بالخيبة']
# Phrase 8 words (without diacritics): ['وسماء', 'اللهفة']
# Phrase 9 words (without diacritics): ['تمطر', 'القبلات', 'بحرارة']
# Phrase 10 words (without diacritics): ['لم', 'أكن', 'أحمل', 'مظلة', 'تقيني']
# Phrase 11 words (without diacritics): ['وابل', 'سحرك']
# Phrase 12 words (without diacritics): ['لم', 'أكن', 'ألبس', 'معطفا']
# Phrase 13 words (without diacritics): ['يرد', 'عني', 'زمهرير', 'الدهشة']
# Phrase 14 words (without diacritics): ['لم', 'أكن', 'أنتعل', 'سوى']
# Phrase 15 words (without diacritics): ['حذاء', 'الوقت', 'المثقوب']
# Phrase 16 words (without diacritics): ['وهناك']
# Phrase 17 words (without diacritics): ['على', 'قارعة', 'الانتظار']
# Phrase 18 words (without diacritics): ['كنت', 'أرتجف', 'عشقا']
# Phrase 19 words (without diacritics): ['كنت', 'أقف', 'مبللة', 'بالاشتياق']
# Phrase 20 words (without diacritics): ['شيء']
# Phrase 21 words (without diacritics): ['صوت']
# Phrase 22 words (without diacritics): ['سوى', 'زخات', 'نبض', 'يروي']
# Phrase 23 words (without diacritics): ['ظمأ', 'الروح', 'القاحلة']
# Phrase 24 words (without diacritics): ['منذ', 'عهد', 'المجاعة', 'الحب']
# Phrase 25 words (without diacritics): ['قوس', 'قزح', 'بهائك']
# Phrase 26 words (without diacritics): ['هزم', 'عتمة', 'وحدتي']
# Phrase 27 words (without diacritics): ['جسدان']
# Phrase 28 words (without diacritics): ['جسدان', 'يشعلان', 'حطب', 'الوصال']
# Phrase 29 words (without diacritics): ['حتى', 'انطفاء', 'لهب', 'الرغبة']
# Phrase 30 words (without diacritics): ['فنجانان', 'من', 'قهوة', 'الحب']
# Phrase 31 words (without diacritics): ['وبعض', 'من', 'كستناء', 'الفرح']
# Phrase 32 words (without diacritics): ['زاد', 'عاشقين']
# Phrase 33 words (without diacritics): ['حتى', 'إشعار', 'آخر', 'من', 'العناق']
# Phrase 34 words (without diacritics): ['وأمضي']
# Phrase 35 words (without diacritics): ['أتوكأ', 'حزني']
# Phrase 36 words (without diacritics): ['رعد', 'وبرق', 'وليل']
# Phrase 37 words (without diacritics): ['يتكسر', 'حذائي', 'البلوري']
# Phrase 38 words (without diacritics): ['وأتعثر', 'خطوات', 'ظلك', 'المسافر']
# Phrase 39 words (without diacritics): ['محطات', 'الرجاء']
# Phrase 40 words (without diacritics): ['مطر', 'مطر']
# Phrase 41 words (without diacritics): ['تتبلل', 'أرصفة', 'الوجد']
# Phrase 42 words (without diacritics): ['تنهمر', 'مزاريب', 'الذاكرة']
# Phrase 43 words (without diacritics): ['فيهذي', 'القلب']
# Phrase 44 words (without diacritics): ['كانت', 'لحظات', 'من', 'ياسمين']
# Phrase 45 words (without diacritics): ['يشم', 'عطرها']
# Phrase 46 words (without diacritics): ['إلا', 'بستاني', 'بارع', 'في', 'تشذيب', 'الأماني']
# Phrase 47 words (without diacritics): ['مطر', 'مطر']
# Phrase 48 words (without diacritics): ['سنوات', 'مرت']
# Phrase 49 words (without diacritics): ['وأنا', 'أعقد', 'ربطة', 'عنق', 'الوقت']
# Phrase 50 words (without diacritics): ['أكوي', 'الأمل', 'المجعد']
# Phrase 51 words (without diacritics): ['وأزرر', 'قمصان', 'غيابك']
# Phrase 52 words (without diacritics): ['سنوات', 'مرت']
# Phrase 53 words (without diacritics): ['وأنا', 'أطعم', 'عصافير', 'قلبي']
# Phrase 54 words (without diacritics): ['من', 'قمح', 'الصبر']
# Phrase 55 words (without diacritics): ['وأهرب', 'إليها']
# Phrase 56 words (without diacritics): ['الماء', 'الصالح', 'للحب']
# Phrase 57 words (without diacritics): ['سنوات', 'مرت']
# Phrase 58 words (without diacritics): ['وأنا', 'أزركش', 'فساتين', 'قصائدي']
# Phrase 59 words (without diacritics): ['بفراشات', 'الوعد']
# Phrase 60 words (without diacritics): ['وأزرع', 'لها']
# Phrase 61 words (without diacritics): ['الورد', 'المعرش', 'على', 'جدران', 'روحي']
# Phrase 62 words (without diacritics): ['سنوات', 'مرت']
# Phrase 63 words (without diacritics): ['ومازالت', 'الذاكرة', 'مصابة']
# Phrase 64 words (without diacritics): ['بحمى', 'عشقك']
# Phrase 65 words (without diacritics): ['سنوات', 'مرت']
# Phrase 66 words (without diacritics): ['ومازالت', 'الروح', 'تتذكر']
# Phrase 67 words (without diacritics): ['أنها', 'التقتك']
# Phrase 68 words (without diacritics): ['عندما', 'كنت', 'تعبر']
# Phrase 69 words (without diacritics): ['إلى', 'الضفة', 'الأخرى']
# Phrase 70 words (without diacritics): ['من', 'الشعر']
# Phrase 71 words (without diacritics): ['البحر']
# Phrase 72 words (without diacritics): ['أول', 'مستقبل']
# Phrase 73 words (without diacritics): ['آخر', 'خطوي', 'اليابسة']
# Phrase 74 words (without diacritics): ['وصولي']
# Phrase 75 words (without diacritics): ['يلوح', 'بعيد']
# Phrase 76 words (without diacritics): ['بأمواجه']
# Phrase 77 words (without diacritics): ['يقذفها', 'عاليا']
# Phrase 78 words (without diacritics): ['فتعود', 'إليه', 'فأعرف', 'مشيرا', 'إلي']
# Phrase 79 words (without diacritics): ['يدل']
# Phrase 80 words (without diacritics): ['ينادي', 'نتظارك', 'صاحبي']
# Phrase 81 words (without diacritics): ['رحت', 'أسعى', 'بجد', 'إليه']
# Phrase 82 words (without diacritics): ['ورأسي', 'تجيء', 'إلي']
# Phrase 83 words (without diacritics): ['بعالمه', 'المشتهى']
# Phrase 84 words (without diacritics): ['يتشكل', 'ضد', 'الرؤى', 'البائسة']
# Phrase 85 words (without diacritics): ['كنت', 'أتخيل', 'مياها']
# Phrase 86 words (without diacritics): ['بلا', 'آخر']
# Phrase 87 words (without diacritics): ['ظني', 'بأن', 'البحار']
# Phrase 88 words (without diacritics): ['كبحر', 'يوسف', 'الحقول']
# Phrase 89 words (without diacritics): ['يعيش', 'أليفا']
# Phrase 90 words (without diacritics): ['شاطئان']
# Phrase 91 words (without diacritics): ['وبعض', 'العطايا']
# Phrase 92 words (without diacritics): ['وأسطورته']
# Phrase 93 words (without diacritics): ['حكمة', 'هامسة']
# Phrase 94 words (without diacritics): ['أكن', 'أدرك', 'العمق']
# Phrase 95 words (without diacritics): ['وضعفي']
# Phrase 96 words (without diacritics): ['كنت', 'أدري', 'بأني']
# Phrase 97 words (without diacritics): ['دخلت', 'فصولا']
# Phrase 98 words (without diacritics): ['ستمحو']
# Phrase 99 words (without diacritics): ['وتعطي']
# Phrase 100 words (without diacritics): ['وتثبت', 'لون']

# %%
# Normalization
import unicodedata

def normalize_words(words):
    normalized_words = []
    for word in words:
        # Check if the word is a list (nested list)
        if isinstance(word, list):
            # If it's a nested list, recursively call normalize_words
            normalized_sublist = normalize_words(word)
            normalized_words.append(normalized_sublist)
        else:
            # Unicode normalization (NFKD form)
            normalized_word = unicodedata.normalize('NFKD', word)
        
            # Case normalization (convert to lowercase)
            normalized_word = normalized_word.lower()
        
            # Whitespace normalization (replace multiple spaces with a single space)
            normalized_word = ' '.join(normalized_word.split())
        
            normalized_words.append(normalized_word)
    
    return normalized_words

# Normalize cleaned words
normalized_words = normalize_words(cleaned_words)

# Print normalized words
for i, word in enumerate(normalized_words[:100]):  # Print the first few normalized words
    print(f"Normalized word {i+1}:", word)
# Out:
# Normalized word 1: ['كان', 'الفصل', 'شغفا']
# Normalized word 2: ['وكانت', 'الساعة']
# Normalized word 3: ['متجمدة', 'عقارب', 'العناق']
# Normalized word 4: ['نوافذ', 'القلب', 'خلعتها']
# Normalized word 5: ['أعاصير', 'اللوعة']
# Normalized word 6: ['ستائر', 'الروح']
# Normalized word 7: ['من', 'دانتيل', 'منقط', 'بالخيبة']
# Normalized word 8: ['وسماء', 'اللهفة']
# Normalized word 9: ['تمطر', 'القبلات', 'بحرارة']
# Normalized word 10: ['لم', 'أكن', 'أحمل', 'مظلة', 'تقيني']
# Normalized word 11: ['وابل', 'سحرك']
# Normalized word 12: ['لم', 'أكن', 'ألبس', 'معطفا']
# Normalized word 13: ['يرد', 'عني', 'زمهرير', 'الدهشة']
# Normalized word 14: ['لم', 'أكن', 'أنتعل', 'سوى']
# Normalized word 15: ['حذاء', 'الوقت', 'المثقوب']
# Normalized word 16: ['وهناك']
# Normalized word 17: ['على', 'قارعة', 'الانتظار']
# Normalized word 18: ['كنت', 'أرتجف', 'عشقا']
# Normalized word 19: ['كنت', 'أقف', 'مبللة', 'بالاشتياق']
# Normalized word 20: ['شيء']
# Normalized word 21: ['صوت']
# Normalized word 22: ['سوى', 'زخات', 'نبض', 'يروي']
# Normalized word 23: ['ظمأ', 'الروح', 'القاحلة']
# Normalized word 24: ['منذ', 'عهد', 'المجاعة', 'الحب']
# Normalized word 25: ['قوس', 'قزح', 'بهائك']
# Normalized word 26: ['هزم', 'عتمة', 'وحدتي']
# Normalized word 27: ['جسدان']
# Normalized word 28: ['جسدان', 'يشعلان', 'حطب', 'الوصال']
# Normalized word 29: ['حتى', 'انطفاء', 'لهب', 'الرغبة']
# Normalized word 30: ['فنجانان', 'من', 'قهوة', 'الحب']
# Normalized word 31: ['وبعض', 'من', 'كستناء', 'الفرح']
# Normalized word 32: ['زاد', 'عاشقين']
# Normalized word 33: ['حتى', 'إشعار', 'آخر', 'من', 'العناق']
# Normalized word 34: ['وأمضي']
# Normalized word 35: ['أتوكأ', 'حزني']
# Normalized word 36: ['رعد', 'وبرق', 'وليل']
# Normalized word 37: ['يتكسر', 'حذائي', 'البلوري']
# Normalized word 38: ['وأتعثر', 'خطوات', 'ظلك', 'المسافر']
# Normalized word 39: ['محطات', 'الرجاء']
# Normalized word 40: ['مطر', 'مطر']
# Normalized word 41: ['تتبلل', 'أرصفة', 'الوجد']
# Normalized word 42: ['تنهمر', 'مزاريب', 'الذاكرة']
# Normalized word 43: ['فيهذي', 'القلب']
# Normalized word 44: ['كانت', 'لحظات', 'من', 'ياسمين']
# Normalized word 45: ['يشم', 'عطرها']
# Normalized word 46: ['إلا', 'بستاني', 'بارع', 'في', 'تشذيب', 'الأماني']
# Normalized word 47: ['مطر', 'مطر']
# Normalized word 48: ['سنوات', 'مرت']
# Normalized word 49: ['وأنا', 'أعقد', 'ربطة', 'عنق', 'الوقت']
# Normalized word 50: ['أكوي', 'الأمل', 'المجعد']
# Normalized word 51: ['وأزرر', 'قمصان', 'غيابك']
# Normalized word 52: ['سنوات', 'مرت']
# Normalized word 53: ['وأنا', 'أطعم', 'عصافير', 'قلبي']
# Normalized word 54: ['من', 'قمح', 'الصبر']
# Normalized word 55: ['وأهرب', 'إليها']
# Normalized word 56: ['الماء', 'الصالح', 'للحب']
# Normalized word 57: ['سنوات', 'مرت']
# Normalized word 58: ['وأنا', 'أزركش', 'فساتين', 'قصائدي']
# Normalized word 59: ['بفراشات', 'الوعد']
# Normalized word 60: ['وأزرع', 'لها']
# Normalized word 61: ['الورد', 'المعرش', 'على', 'جدران', 'روحي']
# Normalized word 62: ['سنوات', 'مرت']
# Normalized word 63: ['ومازالت', 'الذاكرة', 'مصابة']
# Normalized word 64: ['بحمى', 'عشقك']
# Normalized word 65: ['سنوات', 'مرت']
# Normalized word 66: ['ومازالت', 'الروح', 'تتذكر']
# Normalized word 67: ['أنها', 'التقتك']
# Normalized word 68: ['عندما', 'كنت', 'تعبر']
# Normalized word 69: ['إلى', 'الضفة', 'الأخرى']
# Normalized word 70: ['من', 'الشعر']
# Normalized word 71: ['البحر']
# Normalized word 72: ['أول', 'مستقبل']
# Normalized word 73: ['آخر', 'خطوي', 'اليابسة']
# Normalized word 74: ['وصولي']
# Normalized word 75: ['يلوح', 'بعيد']
# Normalized word 76: ['بأمواجه']
# Normalized word 77: ['يقذفها', 'عاليا']
# Normalized word 78: ['فتعود', 'إليه', 'فأعرف', 'مشيرا', 'إلي']
# Normalized word 79: ['يدل']
# Normalized word 80: ['ينادي', 'نتظارك', 'صاحبي']
# Normalized word 81: ['رحت', 'أسعى', 'بجد', 'إليه']
# Normalized word 82: ['ورأسي', 'تجيء', 'إلي']
# Normalized word 83: ['بعالمه', 'المشتهى']
# Normalized word 84: ['يتشكل', 'ضد', 'الرؤى', 'البائسة']
# Normalized word 85: ['كنت', 'أتخيل', 'مياها']
# Normalized word 86: ['بلا', 'آخر']
# Normalized word 87: ['ظني', 'بأن', 'البحار']
# Normalized word 88: ['كبحر', 'يوسف', 'الحقول']
# Normalized word 89: ['يعيش', 'أليفا']
# Normalized word 90: ['شاطئان']
# Normalized word 91: ['وبعض', 'العطايا']
# Normalized word 92: ['وأسطورته']
# Normalized word 93: ['حكمة', 'هامسة']
# Normalized word 94: ['أكن', 'أدرك', 'العمق']
# Normalized word 95: ['وضعفي']
# Normalized word 96: ['كنت', 'أدري', 'بأني']
# Normalized word 97: ['دخلت', 'فصولا']
# Normalized word 98: ['ستمحو']
# Normalized word 99: ['وتعطي']
# Normalized word 100: ['وتثبت', 'لون']

# %%
# Stemming
from nltk.stem import SnowballStemmer

# Initialize SnowballStemmer for Arabic
stemmer = SnowballStemmer("arabic")

# Flatten nested lists
def flatten_list(lst):
    flat_list = []
    for item in lst:
        if isinstance(item, list):
            flat_list.extend(flatten_list(item))
        else:
            flat_list.append(item)
    return flat_list

# Flatten the normalized words
flat_normalized_words = flatten_list(normalized_words)

# Stem the normalized words
stemmed_words = [stemmer.stem(word) for word in flat_normalized_words]

# Print the stemmed words
for i, word in enumerate(stemmed_words[:100]):  # Print the first few stemmed words
    print(f"Stemmed word {i+1}:", word)
# Out:
# Stemmed word 1: كان
# Stemmed word 2: فصل
# Stemmed word 3: شغف
# Stemmed word 4: كان
# Stemmed word 5: ساع
# Stemmed word 6: متجمد
# Stemmed word 7: عقارب
# Stemmed word 8: عناق
# Stemmed word 9: نوافذ
# Stemmed word 10: قلب
# Stemmed word 11: خلع
# Stemmed word 12: أعاصير
# Stemmed word 13: لوع
# Stemmed word 14: ستائر
# Stemmed word 15: روح
# Stemmed word 16: من
# Stemmed word 17: دانتيل
# Stemmed word 18: منقط
# Stemmed word 19: خيب
# Stemmed word 20: سماء
# Stemmed word 21: لهف
# Stemmed word 22: تمطر
# Stemmed word 23: قبل
# Stemmed word 24: حرار
# Stemmed word 25: لم
# Stemmed word 26: أك
# Stemmed word 27: أحمل
# Stemmed word 28: مظل
# Stemmed word 29: تق
# Stemmed word 30: وابل
# Stemmed word 31: سحر
# Stemmed word 32: لم
# Stemmed word 33: أك
# Stemmed word 34: ألبس
# Stemmed word 35: معطف
# Stemmed word 36: يرد
# Stemmed word 37: عن
# Stemmed word 38: زمهرير
# Stemmed word 39: دهش
# Stemmed word 40: لم
# Stemmed word 41: أك
# Stemmed word 42: أنتعل
# Stemmed word 43: سوى
# Stemmed word 44: حذاء
# Stemmed word 45: الو
# Stemmed word 46: مثقوب
# Stemmed word 47: وهن
# Stemmed word 48: على
# Stemmed word 49: قارع
# Stemmed word 50: انتظار
# Stemmed word 51: كنت
# Stemmed word 52: أرتجف
# Stemmed word 53: عشق
# Stemmed word 54: كنت
# Stemmed word 55: أقف
# Stemmed word 56: مبلل
# Stemmed word 57: اشتياق
# Stemmed word 58: شيء
# Stemmed word 59: صوت
# Stemmed word 60: سوى
# Stemmed word 61: زخا
# Stemmed word 62: نبض
# Stemmed word 63: يرو
# Stemmed word 64: ظمأ
# Stemmed word 65: روح
# Stemmed word 66: قاحل
# Stemmed word 67: منذ
# Stemmed word 68: عهد
# Stemmed word 69: مجاع
# Stemmed word 70: الحب
# Stemmed word 71: قوس
# Stemmed word 72: قزح
# Stemmed word 73: هائ
# Stemmed word 74: هزم
# Stemmed word 75: عتم
# Stemmed word 76: وحد
# Stemmed word 77: جسدا
# Stemmed word 78: جسدا
# Stemmed word 79: يشعل
# Stemmed word 80: حطب
# Stemmed word 81: وصال
# Stemmed word 82: حتى
# Stemmed word 83: انطفاء
# Stemmed word 84: لهب
# Stemmed word 85: رغب
# Stemmed word 86: نجا
# Stemmed word 87: من
# Stemmed word 88: قهو
# Stemmed word 89: الحب
# Stemmed word 90: بعض
# Stemmed word 91: من
# Stemmed word 92: ستناء
# Stemmed word 93: فرح
# Stemmed word 94: زاد
# Stemmed word 95: عاشق
# Stemmed word 96: حتى
# Stemmed word 97: إشعار
# Stemmed word 98: آخر
# Stemmed word 99: من
# Stemmed word 100: عناق

# %%
# Lemmatization
from nltk.stem import WordNetLemmatizer

# Initialize WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Flatten nested lists
def flatten_list(lst):
    flat_list = []
    for item in lst:
        if isinstance(item, list):
            flat_list.extend(flatten_list(item))
        else:
            flat_list.append(item)
    return flat_list

# Flatten the normalized words
flat_normalized_words = flatten_list(normalized_words)

# Lemmatize the flattened words
lemmatized_words = [lemmatizer.lemmatize(word) for word in flat_normalized_words]

# Print the lemmatized words
for i, word in enumerate(lemmatized_words[:100]):  # Print the first few lemmatized words
    print(f"Lemmatized word {i+1}:", word)
# Out:
# Lemmatized word 1: كان
# Lemmatized word 2: الفصل
# Lemmatized word 3: شغفا
# Lemmatized word 4: وكانت
# Lemmatized word 5: الساعة
# Lemmatized word 6: متجمدة
# Lemmatized word 7: عقارب
# Lemmatized word 8: العناق
# Lemmatized word 9: نوافذ
# Lemmatized word 10: القلب
# Lemmatized word 11: خلعتها
# Lemmatized word 12: أعاصير
# Lemmatized word 13: اللوعة
# Lemmatized word 14: ستائر
# Lemmatized word 15: الروح
# Lemmatized word 16: من
# Lemmatized word 17: دانتيل
# Lemmatized word 18: منقط
# Lemmatized word 19: بالخيبة
# Lemmatized word 20: وسماء
# Lemmatized word 21: اللهفة
# Lemmatized word 22: تمطر
# Lemmatized word 23: القبلات
# Lemmatized word 24: بحرارة
# Lemmatized word 25: لم
# Lemmatized word 26: أكن
# Lemmatized word 27: أحمل
# Lemmatized word 28: مظلة
# Lemmatized word 29: تقيني
# Lemmatized word 30: وابل
# Lemmatized word 31: سحرك
# Lemmatized word 32: لم
# Lemmatized word 33: أكن
# Lemmatized word 34: ألبس
# Lemmatized word 35: معطفا
# Lemmatized word 36: يرد
# Lemmatized word 37: عني
# Lemmatized word 38: زمهرير
# Lemmatized word 39: الدهشة
# Lemmatized word 40: لم
# Lemmatized word 41: أكن
# Lemmatized word 42: أنتعل
# Lemmatized word 43: سوى
# Lemmatized word 44: حذاء
# Lemmatized word 45: الوقت
# Lemmatized word 46: المثقوب
# Lemmatized word 47: وهناك
# Lemmatized word 48: على
# Lemmatized word 49: قارعة
# Lemmatized word 50: الانتظار
# Lemmatized word 51: كنت
# Lemmatized word 52: أرتجف
# Lemmatized word 53: عشقا
# Lemmatized word 54: كنت
# Lemmatized word 55: أقف
# Lemmatized word 56: مبللة
# Lemmatized word 57: بالاشتياق
# Lemmatized word 58: شيء
# Lemmatized word 59: صوت
# Lemmatized word 60: سوى
# Lemmatized word 61: زخات
# Lemmatized word 62: نبض
# Lemmatized word 63: يروي
# Lemmatized word 64: ظمأ
# Lemmatized word 65: الروح
# Lemmatized word 66: القاحلة
# Lemmatized word 67: منذ
# Lemmatized word 68: عهد
# Lemmatized word 69: المجاعة
# Lemmatized word 70: الحب
# Lemmatized word 71: قوس
# Lemmatized word 72: قزح
# Lemmatized word 73: بهائك
# Lemmatized word 74: هزم
# Lemmatized word 75: عتمة
# Lemmatized word 76: وحدتي
# Lemmatized word 77: جسدان
# Lemmatized word 78: جسدان
# Lemmatized word 79: يشعلان
# Lemmatized word 80: حطب
# Lemmatized word 81: الوصال
# Lemmatized word 82: حتى
# Lemmatized word 83: انطفاء
# Lemmatized word 84: لهب
# Lemmatized word 85: الرغبة
# Lemmatized word 86: فنجانان
# Lemmatized word 87: من
# Lemmatized word 88: قهوة
# Lemmatized word 89: الحب
# Lemmatized word 90: وبعض
# Lemmatized word 91: من
# Lemmatized word 92: كستناء
# Lemmatized word 93: الفرح
# Lemmatized word 94: زاد
# Lemmatized word 95: عاشقين
# Lemmatized word 96: حتى
# Lemmatized word 97: إشعار
# Lemmatized word 98: آخر
# Lemmatized word 99: من
# Lemmatized word 100: العناق

# %%
# POS tagging
import stanza

# Initialize Stanza pipeline for Arabic
nlp = stanza.Pipeline(lang='ar', processors='tokenize,pos')

# Convert the first 100 lemmatized words to a single string
text = ' '.join(lemmatized_words[:100])

# Perform POS tagging using Stanza
doc = nlp(text)

# Extract POS tags
pos_tags = [(word.text, word.upos) for sent in doc.sentences for word in sent.words]

# Print the POS tags
for i, (word, pos_tag) in enumerate(pos_tags):
    print(f"Word {i+1}: {word} - POS tag: {pos_tag}")
# Out:
# 2024-04-08 04:53:48 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-04-08 04:53:49 INFO: Downloaded file to C:\Users\Yasmine\stanza_resources\resources.json
# 2024-04-08 04:53:49 WARNING: Language ar package default expects mwt, which has been added
# 2024-04-08 04:53:50 INFO: Loading these models for language: ar (Arabic):
# ===========================
# | Processor | Package     |
# ---------------------------
# | tokenize  | padt        |
# | mwt       | padt        |
# | pos       | padt_charlm |
# ===========================
#
# 2024-04-08 04:53:50 INFO: Using device: cpu
# 2024-04-08 04:53:50 INFO: Loading: tokenize
# 2024-04-08 04:53:50 INFO: Loading: mwt
# 2024-04-08 04:53:50 INFO: Loading: pos
# 2024-04-08 04:53:50 INFO: Done loading processors!
# Word 1: كان - POS tag: VERB
# Word 2: الفصل - POS tag: NOUN
# Word 3: شغفا - POS tag: NOUN
# Word 4: وكانت - POS tag: VERB
# Word 5: الساعة - POS tag: NOUN
# Word 6: متجمدة - POS tag: ADJ
# Word 7: عقارب - POS tag: NOUN
# Word 8: العناق - POS tag: NOUN
# Word 9: نوافذ - POS tag: X
# Word 10: القلب - POS tag: NOUN
# Word 11: خلعت - POS tag: VERB
# Word 12: ها - POS tag: PRON
# Word 13: أعاصير - POS tag: X
# Word 14: اللوعة - POS tag: NOUN
# Word 15: س - POS tag: AUX
# Word 16: تاي<UNK>ر - POS tag: X
# Word 17: الروح - POS tag: NOUN
# Word 18: من - POS tag: ADP
# Word 19: دانتيل - POS tag: X
# Word 20: منقط - POS tag: X
# Word 21: ب - POS tag: ADP
# Word 22: الخيبة - POS tag: NOUN
# Word 23: و - POS tag: CCONJ
# Word 24: سماء - POS tag: NOUN
# Word 25: اللهفة - POS tag: NOUN
# Word 26: تمطر - POS tag: VERB
# Word 27: القبلات - POS tag: NOUN
# Word 28: ب - POS tag: ADP
# Word 29: حرارة - POS tag: NOUN
# Word 30: لم - POS tag: PART
# Word 31: أكن - POS tag: VERB
# Word 32: أحمل - POS tag: ADJ
# Word 33: مظلة - POS tag: NOUN
# Word 34: تقيني - POS tag: X
# Word 35: و - POS tag: CCONJ
# Word 36: أبل - POS tag: X
# Word 37: س - POS tag: AUX
# Word 38: حرك - POS tag: VERB
# Word 39: لم - POS tag: PART
# Word 40: أكن - POS tag: X
# Word 41: ألبس - POS tag: NOUN
# Word 42: معطفا - POS tag: NOUN
# Word 43: يرد - POS tag: VERB
# Word 44: عني - POS tag: ADP
# Word 45: زمهرير - POS tag: NOUN
# Word 46: الدهشة - POS tag: NOUN
# Word 47: لم - POS tag: PART
# Word 48: أكن - POS tag: VERB
# Word 49: أنتعل - POS tag: X
# Word 50: سوى - POS tag: ADP
# Word 51: حذاء - POS tag: NOUN
# Word 52: الوقت - POS tag: NOUN
# Word 53: المثقوب - POS tag: ADJ
# Word 54: و - POS tag: CCONJ
# Word 55: هناك - POS tag: ADV
# Word 56: على - POS tag: ADP
# Word 57: قارعة - POS tag: NOUN
# Word 58: الانتظار - POS tag: NOUN
# Word 59: كنت - POS tag: VERB
# Word 60: أرتجف - POS tag: X
# Word 61: عشقا - POS tag: NOUN
# Word 62: كنت - POS tag: VERB
# Word 63: أقف - POS tag: X
# Word 64: مبللة - POS tag: ADJ
# Word 65: ب - POS tag: ADP
# Word 66: الاشتياق - POS tag: NOUN
# Word 67: شيء - POS tag: NOUN
# Word 68: صوت - POS tag: NOUN
# Word 69: سوى - POS tag: ADP
# Word 70: زخات - POS tag: NOUN
# Word 71: نبض - POS tag: NOUN
# Word 72: يروي - POS tag: VERB
# Word 73: ظمأ - POS tag: X
# Word 74: الروح - POS tag: NOUN
# Word 75: القاحلة - POS tag: ADJ
# Word 76: منذ - POS tag: ADP
# Word 77: عهد - POS tag: NOUN
# Word 78: المجاعة - POS tag: NOUN
# Word 79: الحب - POS tag: NOUN
# Word 80: قوس - POS tag: NOUN
# Word 81: قزح - POS tag: X
# Word 82: ب - POS tag: ADP
# Word 83: هاي<UNK> - POS tag: NOUN
# Word 84: ك - POS tag: ADP
# Word 85: هزم - POS tag: VERB
# Word 86: عتمة - POS tag: NOUN
# Word 87: و - POS tag: CCONJ
# Word 88: حدتي - POS tag: NOUN
# Word 89: جسدان - POS tag: NOUN
# Word 90: جسدان - POS tag: ADJ
# Word 91: يشعلان - POS tag: VERB
# Word 92: حطب - POS tag: NOUN
# Word 93: الوصال - POS tag: NOUN
# Word 94: حتى - POS tag: ADV
# Word 95: انطفاء - POS tag: NOUN
# Word 96: ل - POS tag: ADP
# Word 97: هب - POS tag: NOUN
# Word 98: الرغبة - POS tag: NOUN
# Word 99: فنجانان - POS tag: X
# Word 100: من - POS tag: ADP
# Word 101: قهوة - POS tag: NOUN
# Word 102: الحب - POS tag: NOUN
# Word 103: و - POS tag: CCONJ
# Word 104: بعض - POS tag: NOUN
# Word 105: من - POS tag: ADP
# Word 106: كستناء - POS tag: X
# Word 107: الفرح - POS tag: NOUN
# Word 108: زاد - POS tag: VERB
# Word 109: عاشقين - POS tag: NOUN
# Word 110: حتى - POS tag: ADV
# Word 111: إشعار - POS tag: X
# Word 112: آخر - POS tag: X
# Word 113: من - POS tag: ADP
# Word 114: العناق - POS tag: NOUN

# %%
# Import stanza
import stanza

# Initialize Stanza pipeline for Arabic with NER enabled
nlp = stanza.Pipeline(lang='ar', processors='tokenize,ner')

# Convert the first 100 lemmatized words to a single string
text = ' '.join(lemmatized_words[:1000])

# Perform NER using Stanza
doc = nlp(text)

# Extract NER tags
ner_tags = [(ent.text, ent.type) for sent in doc.sentences for ent in sent.ents]

# Print the NER tags
for i, (entity, entity_type) in enumerate(ner_tags):
    print(f"Entity {i+1}: {entity} - Type: {entity_type}")
# Out:
# 2024-04-08 05:07:27 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-04-08 05:07:29 INFO: Downloaded file to C:\Users\Yasmine\stanza_resources\resources.json
# 2024-04-08 05:07:29 WARNING: Language ar package default expects mwt, which has been added
# 2024-04-08 05:07:30 INFO: Loading these models for language: ar (Arabic):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | padt         |
# | mwt       | padt         |
# | ner       | aqmar_charlm |
# ============================
#
# 2024-04-08 05:07:30 INFO: Using device: cpu
# 2024-04-08 05:07:30 INFO: Loading: tokenize
# 2024-04-08 05:07:30 INFO: Loading: mwt
# 2024-04-08 05:07:30 INFO: Loading: ner
# 2024-04-08 05:07:32 INFO: Done loading processors!
# Entity 1: العرب - Type: PER
# Entity 2: تونس - Type: LOC
# Entity 3: الشام - Type: LOC
